# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import arviz as az
import stan_jupyter as stan
import pandas as pd

# %% [markdown]
# ## Easy

# %% [markdown]
# __4E1__
#
# The likelihood is line 1: $y_i \sim Normal(\mu, \sigma)$
#
# __4E2__
#
# There are two parameters ($\mu$ and $\sigma$) in the model:
#
#
# \begin{align}
# y_i &\sim Normal(\mu, \sigma) \\
# \mu &\sim Normal(0, 10) \\
# \sigma &\sim Exponential(1)
# \end{align}
#
#
# __4E3__
#
# $$ Pr(\mu, \sigma | y) = \frac{Normal(y|\mu, \sigma) Normal(\mu|0, 10)Exponential(\sigma|1)}
# {\int\int Normal(y|\mu, sigma)Normal(\mu|0, 10)Exponential(\sigma|1)d\mu d\sigma}$$
#
# __4E4__
#
# The linear model is in the second line: $\mu_i = \alpha + \beta x_i$
#
# __4E5__
#
# The model below has three parameters: $\alpha, \beta$ and $\sigma $:
# \begin{align}
# y_i &\sim Normal(\mu, \sigma) \\
# \mu &= \alpha + \beta x_i \\
# \alpha &\sim Normal(0, 10) \\
# \beta &\sim Normal(0,1) \\
# \sigma &\sim Exponential(2)
# \end{align}

# %% [markdown]
# ## Medium

# %% [markdown]
# __4M1__

# %%
size = 10000
sample_mu = stats.norm.rvs(0, 10, size)
sample_sigma = stats.expon.rvs(1, size=size)
sample_y = stats.norm.rvs(sample_mu, sample_sigma, size)

# %%
az.plot_kde(sample_y)
# Out:
# <AxesSubplot:>

# %% [markdown]
# __4M2__
#
# _Skipping because it is specific to R._
#
# __4M3__
#
# \begin{align}
# y_i &\sim Normal(\mu, sigma) \\
# \mu &= \alpha + \beta x_i \\
# \alpha &\sim Normal(0, 10) \\
# \beta &\sim Uniform(0, 1) \\
# \sigma &\sim Exponential(1)
# \end{align}
#
# __4M4__
#
# \begin{align}
# height_{it} &\sim Normal(\mu_{it}, \sigma) \\
# \mu_{it} &= \alpha + \beta * (year_t - \bar y) \\
# \alpha &\sim Normal(140,20) \\
# \beta &\sim Normal(10, 10) \\
# \sigma &\sim Exponential(1) \\
# \end{align}
#
# __4M5__
#
# Since logically students will get taller each year, the slope of $\beta$ should be positive.
#
# \begin{align}
# height_{it} &\sim Normal(\mu_{it}, \sigma) \\
# \mu_{it} &= \alpha + \beta * (year_t - \bar y) \\
# \alpha &\sim Normal(140,20) \\
# \beta &\sim HalfNormal(10, 10) \\
# \sigma &\sim Exponential(1) \\
# \end{align}
#
# __4M6__
#
# If we know the variance between students of the same age <= 64, that means the standard deviation <= 8. In that case, we can change sigma (the standard deviation) to have a uniform prior with a hard ceiling of 8 (and a floor of 0, because a negative standard deviation isn't possible).
#
#
# \begin{align}
# height_{it} &\sim Normal(\mu_{it}, \sigma) \\
# \mu_{it} &= \alpha + \beta * (year_t - \bar y) \\
# \alpha &\sim Normal(140, 20) \\
# \beta &\sim HalfNormal(10, 10) \\
# \sigma &\sim Uniform(0, 8) \\
# \end{align}
#
# __4M7__

# %%
df = pd.read_csv("../../data/Howell1.csv", delimiter=";")
df = df[df.age>=18]

# %%
with open('models/model_4_3.stan', 'r') as f:
    model_code = f.read()

model_data = {"N":len(df),
              "height":df.height.values.tolist(),
              "weight":df.weight.values.tolist()
             }

# %%
posterior = stan.build(model_code, model_data)

fit = posterior.sample(num_chains=4, num_samples=1000)
# Out:
# Building: found in cache, done.
# Messages from stanc:
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_61wmbn97/model_nfeudqqy.stan', line 20, column 41: A normal distribution is given parameter sigma as a scale parameter (argument 2), but sigma was not constrained to be strictly positive.
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_61wmbn97/model_nfeudqqy.stan', line 17, column 21: Argument 50 suggests there may be parameters that are not unit scale; consider rescaling with a multiplier (see manual section 22.12).
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_61wmbn97/model_nfeudqqy.stan', line 17, column 2: Parameter sigma is given a uniform distribution. The uniform distribution is not recommended, for two reasons: (a) Except when there are logical or physical constraints, it is very unusual for you to be sure that a parameter will fall inside a specified range, and (b) The infinite gradient induced by a uniform density can cause difficulties for Stan's sampling algorithm. As a consequence, we recommend soft constraints rather than hard constraints; for example, instead of giving an elasticity parameter a uniform(0,1) distribution, try normal(0.5,0.5).
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_61wmbn97/model_nfeudqqy.stan', line 16, column 2: Parameter beta is given a lognormal distribution, which has strictly positive support, but beta was not constrained to be strictly positive.
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_61wmbn97/model_nfeudqqy.stan', line 15, column 22: Argument 20 suggests there may be parameters that are not unit scale; consider rescaling with a multiplier (see manual section 22.12).
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_61wmbn97/model_nfeudqqy.stan', line 15, column 17: Argument 178 suggests there may be parameters that are not unit scale; consider rescaling with a multiplier (see manual section 22.12).
# Sampling:   0%
# Sampling:   6% (500/8000)
# Sampling:  12% (1000/8000)
# Sampling:  19% (1500/8000)
# Sampling:  44% (3500/8000)
# Sampling:  62% (5000/8000)
# Sampling:  81% (6500/8000)
# Sampling: 100% (8000/8000)
# Sampling: 100% (8000/8000), done.
# Messages received during sampling:
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: normal_lpdf: Scale parameter is -0.723142, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan__pn7ajsd/model_nfeudqqy.stan', line 20, column 2 to column 48)
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: lognormal_lpdf: Random variable is -1.02584, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan__pn7ajsd/model_nfeudqqy.stan', line 16, column 2 to column 25)
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: lognormal_lpdf: Random variable is -0.373242, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan__pn7ajsd/model_nfeudqqy.stan', line 16, column 2 to column 25)
#   Gradient evaluation took 5.8e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.58 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -10.0089, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan__pn7ajsd/model_nfeudqqy.stan', line 20, column 2 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: normal_lpdf: Scale parameter is -1.3481, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan__pn7ajsd/model_nfeudqqy.stan', line 20, column 2 to column 48)
#   Gradient evaluation took 5.5e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.55 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -0.918065, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan__pn7ajsd/model_nfeudqqy.stan', line 16, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -10.6671, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan__pn7ajsd/model_nfeudqqy.stan', line 20, column 2 to column 48)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -0.00588941, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan__pn7ajsd/model_nfeudqqy.stan', line 16, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Gradient evaluation took 5.5e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.55 seconds.
#   Adjust your expectations accordingly!
#   Gradient evaluation took 6.1e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.61 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -0.0631981, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan__pn7ajsd/model_nfeudqqy.stan', line 16, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.

# %%
with open('models/model_4_3_diff.stan', 'r') as f:
    model_code = f.read()

x_bar = df.weight.mean()

model_data = {"N":len(df),
              "height":df.height.values.tolist(),
              "weight":df.weight.values.tolist(),
              "X_BAR":x_bar
             }

# %%
posterior = stan.build(model_code, model_data)

fit_diff = posterior.sample(num_chains=4, num_samples=1000)

# %%
az.plot_trace(fit)
# Out:
# array([[<AxesSubplot:title={'center':'alpha'}>,
#         <AxesSubplot:title={'center':'alpha'}>],
#        [<AxesSubplot:title={'center':'beta'}>,
#         <AxesSubplot:title={'center':'beta'}>],
#        [<AxesSubplot:title={'center':'sigma'}>,
#         <AxesSubplot:title={'center':'sigma'}>]], dtype=object)

# %%
az.plot_trace(fit_diff)
# Out:
# array([[<AxesSubplot:title={'center':'alpha'}>,
#         <AxesSubplot:title={'center':'alpha'}>],
#        [<AxesSubplot:title={'center':'beta'}>,
#         <AxesSubplot:title={'center':'beta'}>],
#        [<AxesSubplot:title={'center':'sigma'}>,
#         <AxesSubplot:title={'center':'sigma'}>]], dtype=object)

# %%
az.summary(fit_diff)
# Out:
#           mean     sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# alpha  154.605  0.276  154.055  155.095      0.006    0.004    2289.0
# beta     0.904  0.042    0.825    0.979      0.001    0.001    2511.0
# sigma    5.102  0.192    4.752    5.456      0.003    0.002    4633.0
#
#        ess_tail  r_hat
# alpha    2047.0    1.0
# beta     2115.0    1.0
# sigma    3194.0    1.0

# %%
az.summary(fit)
# Out:
#           mean     sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# alpha  114.587  1.904  110.886  118.006      0.054    0.038    1249.0
# beta     0.889  0.042    0.813    0.969      0.001    0.001    1255.0
# sigma    5.105  0.194    4.725    5.454      0.004    0.003    1902.0
#
#        ess_tail  r_hat
# alpha    1341.0    1.0
# beta     1489.0    1.0
# sigma    1734.0    1.0

# %% [markdown]
# The difference is primarily in the intercept $\alpha$, which is 154.6 in the original model (which modeled deviations from the average weight $\bar x$), but 114.5 in this version of the model. The model with $\bar x$ makes slightly more sense, because there the intercept $\alpha = 154.6$ represents the actual average height at the sample mean weight. In this model, the intercept is a slightly odd mathematical artifact that suggests that a person with a weight of 0 would still be ~114.5cm tall, which is not reasonable. The nearly identical slope $\beta$ suggests the model generally believes the same thing about the association between weight and height, but the model with $\bar x$ allows us to also say something valid about the intercept.

# %%
df_fit = fit.to_frame()
df_fit_diff = fit_diff.to_frame()

plt.figure(figsize=(20,10))
_, ax = plt.subplots(1, 2, figsize=(20,5))

idxs = np.random.randint(len(df_fit), size=500)
ax[0].plot(df.weight, df.height, "C0o", alpha=.3)
ax[1].plot(df.weight-x_bar, df.height, "C0o", alpha=.3)
ax[0].set_title("Height ~ weight")
ax[1].set_title("Height ~ weight deviation from mean")

for n in [0,1]:
    ax[n].set_ylabel("Height (cm)")
    ax[n].set_xlabel("Weight (kg)")
    
for idx in idxs:
    ax[0].plot(
        df.weight,
        df_fit['alpha'][idx] + df_fit['beta'][idx]*df.weight,
        color='black',
        alpha=.01,
    )
    ax[1].plot(
        df.weight-x_bar,
        df_fit_diff['alpha'][idx] + df_fit_diff['beta'][idx]*(df.weight-x_bar),
        color='black',
        alpha=.01,
    )

# %%
reg = np.array([df_fit['alpha'], df_fit['beta'], df_fit['sigma']])
diff = np.array([df_fit_diff['alpha'], df_fit_diff['beta'], df_fit_diff['sigma']])

# %%
reg_cov = np.cov(reg)
reg_cov.round(2)
# Out:
# array([[ 3.62, -0.08,  0.02],
#        [-0.08,  0.  , -0.  ],
#        [ 0.02, -0.  ,  0.04]])

# %%
diff_cov = np.cov(diff)
diff_cov.round(2)
# Out:
# array([[ 0.08, -0.  ,  0.  ],
#        [-0.  ,  0.  ,  0.  ],
#        [ 0.  ,  0.  ,  0.04]])

# %%
def correlation_from_covariance(covariance): # from https://gist.github.com/wiso/ce2a9919ded228838703c1c7c7dad13b
    v = np.sqrt(np.diag(covariance))
    outer_v = np.outer(v, v)
    correlation = covariance / outer_v
    correlation[covariance == 0] = 0
    return correlation

# %%
correlation_from_covariance(diff_cov).round(2)
# Out:
# array([[ 1.  , -0.  ,  0.01],
#        [-0.  ,  1.  ,  0.01],
#        [ 0.01,  0.01,  1.  ]])

# %%
correlation_from_covariance(reg_cov).round(2)
# Out:
# array([[ 1.  , -0.99,  0.06],
#        [-0.99,  1.  , -0.06],
#        [ 0.06, -0.06,  1.  ]])

# %% [markdown]
# __4M8__

# %% [markdown]
# ## Hard
#
# __4H1__

# %%
fit_diff
# Out:
# <stan.Fit>
# Parameters:
#     alpha: ()
#     beta: ()
#     sigma: ()
# Draws: 4000

# %%
weights = [46.95,
           43.72,
           64.78,
           32.59,
           54.63]

# %%
for weight in weights:
    y_pred = stats.norm.rvs(loc=fit_diff['alpha'] + fit_diff['beta']*(weight-x_bar),
                             scale=fit_diff['sigma'])
    print(f"For weight={weight}kg, predicted height={y_pred.mean().round(2)}cm.")
# Out:
# For weight=46.95kg, predicted height=156.38cm.
# For weight=43.72kg, predicted height=153.5cm.
# For weight=64.78kg, predicted height=172.53cm.
# For weight=32.59kg, predicted height=143.32cm.
# For weight=54.63kg, predicted height=163.39cm.

# %% [markdown]
# __4H2__
#
# __a)__

# %%
df = pd.read_csv("../../data/Howell1.csv", delimiter=";")
df = df[df.age<18]

with open('models/model_4_3_diff.stan', 'r') as f:
    model_code = f.read()

x_bar = df.weight.mean()

model_data = {"N":len(df),
              "height":df.height.values.tolist(),
              "weight":df.weight.values.tolist(),
              "X_BAR":x_bar
             }

posterior = stan.build(model_code, model_data)

fit_u18 = posterior.sample(num_chains=4, num_samples=1000)

# %%
az.summary(fit_u18)
# Out:
#                 mean     sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# alpha        108.382  0.617  107.201  109.503      0.010    0.007    3804.0
# beta           2.715  0.069    2.589    2.843      0.001    0.001    4251.0
# sigma          8.531  0.436    7.711    9.329      0.007    0.005    3681.0
# y_pred[0]    111.720  8.680   94.633  127.284      0.138    0.097    3971.0
# y_pred[1]     95.985  8.501   80.103  111.645      0.134    0.095    3994.0
# ...              ...    ...      ...      ...        ...      ...       ...
# y_pred[187]  105.996  8.328   90.030  121.215      0.131    0.092    4047.0
# y_pred[188]   78.014  8.734   61.789   94.326      0.151    0.107    3353.0
# y_pred[189]   80.108  8.659   64.921   96.923      0.141    0.099    3792.0
# y_pred[190]  142.858  8.495  127.199  158.395      0.131    0.093    4180.0
# y_pred[191]   80.077  8.443   64.740   96.263      0.137    0.097    3791.0
#
#              ess_tail  r_hat
# alpha          3091.0    1.0
# beta           3237.0    1.0
# sigma          2590.0    1.0
# y_pred[0]      4062.0    1.0
# y_pred[1]      3997.0    1.0
# ...               ...    ...
# y_pred[187]    3973.0    1.0
# y_pred[188]    3345.0    1.0
# y_pred[189]    3852.0    1.0
# y_pred[190]    3722.0    1.0
# y_pred[191]    3366.0    1.0
#
# [195 rows x 9 columns]

# %% [markdown]
# This model expects the average u18 person in the Howell data to be 108cm tall, with a standard deviation of 8.5 around that mean. For every 10 unit increase in weight, the model expects a ~ 27 unit increase in height.

# %% [markdown]
# __b)__

# %%
weights = sorted(df.weight)
y_pred = [n.mean() for n in fit_u18['y_pred']]
mu_ci = [np.percentile(fit_u18['alpha']+fit_u18['beta']*(n-x_bar), 
                       [5.5, 94.5]).tolist() for n in weights]

# %%
plt.figure(figsize=(25,8))
az.plot_hdi(df.weight, fit_u18['y_pred'].T, fill_kwargs={'color':'gray', 'alpha':.1})
plt.scatter(df.weight, df.height, alpha=.75)
plt.plot(df.weight, 
         y_pred,
         color='b',
         alpha=.5)
plt.fill_between(weights, [n[0] for n in mu_ci], [n[1] for n in mu_ci], alpha=.25, color='gray')
plt.title("Height ~ weight")
plt.xlabel("Weight (kg)")
plt.ylabel("Height (cm)")
# Out:
# /Users/jikaasik/miniconda/lib/python3.9/site-packages/arviz/stats/stats.py:456: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   warnings.warn(
# Text(0, 0.5, 'Height (cm)')

# %% [markdown]
# __c)__

# %% [markdown]
# It's obvious from plotting the data that the relationship between weight and height is not linear, but the model thinks it is. As a result, it doesn't do a good job in almost any region of weight. It systematically underpredicts high and low values of weight and underpredicts average values. We need to introduce the possibility of curvature into the model.
#
# __4H3__

# %%
df = pd.read_csv("../../data/Howell1.csv", delimiter=";")

# %%
with open('models/model_4_3_log.stan', 'r') as f:
    model_code = f.read()

x_bar = np.log(df.weight).mean()

model_data = {"N":len(df),
              "height":df.height.values.tolist(),
              "weight":np.log(df.weight.values.tolist()),
              "X_BAR":x_bar
             }

posterior = stan.build(model_code, model_data)

fit_log = posterior.sample(num_chains=4, num_samples=1000)
# Out:
# Building: found in cache, done.
# Messages from stanc:
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_inbcf6qp/model_ga4qpwto.stan', line 21, column 49: A normal distribution is given parameter sigma as a scale parameter (argument 2), but sigma was not constrained to be strictly positive.
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_inbcf6qp/model_ga4qpwto.stan', line 18, column 21: Argument 50 suggests there may be parameters that are not unit scale; consider rescaling with a multiplier (see manual section 22.12).
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_inbcf6qp/model_ga4qpwto.stan', line 18, column 2: Parameter sigma is given a uniform distribution. The uniform distribution is not recommended, for two reasons: (a) Except when there are logical or physical constraints, it is very unusual for you to be sure that a parameter will fall inside a specified range, and (b) The infinite gradient induced by a uniform density can cause difficulties for Stan's sampling algorithm. As a consequence, we recommend soft constraints rather than hard constraints; for example, instead of giving an elasticity parameter a uniform(0,1) distribution, try normal(0.5,0.5).
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_inbcf6qp/model_ga4qpwto.stan', line 17, column 2: Parameter beta is given a lognormal distribution, which has strictly positive support, but beta was not constrained to be strictly positive.
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_inbcf6qp/model_ga4qpwto.stan', line 16, column 22: Argument 20 suggests there may be parameters that are not unit scale; consider rescaling with a multiplier (see manual section 22.12).
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_inbcf6qp/model_ga4qpwto.stan', line 16, column 17: Argument 178 suggests there may be parameters that are not unit scale; consider rescaling with a multiplier (see manual section 22.12).
# Sampling:   0%
# Sampling:  25% (2000/8000)
# Sampling:  50% (4000/8000)
# Sampling:  75% (6000/8000)
# Sampling: 100% (8000/8000)
# Sampling: 100% (8000/8000), done.
# Messages received during sampling:
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: normal_lpdf: Scale parameter is -0.723142, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 21, column 2 to column 56)
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: lognormal_lpdf: Random variable is -1.02584, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 17, column 2 to column 25)
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: lognormal_lpdf: Random variable is -0.373242, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 17, column 2 to column 25)
#   Gradient evaluation took 2.4e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.24 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -432.627, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -436.841, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -94.1696, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -17.619, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.468814, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -53.0691, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: normal_lpdf: Scale parameter is -1.3481, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 21, column 2 to column 56)
#   Gradient evaluation took 2.3e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.23 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -1534.91, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -1566, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -339.115, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -42.3407, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Gradient evaluation took 2.3e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.23 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -3132.61, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -3140.57, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -790.403, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -186.819, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -40.34, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -1.53417, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -4.52163, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Gradient evaluation took 2.3e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.23 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -34.7531, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -70.149, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -3.82471, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_6w6zi4de/model_ga4qpwto.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.

# %%
az.summary(fit_log)
# Out:
#                 mean     sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# alpha        138.274  0.221  137.894  138.715      0.004    0.003    3887.0
# beta          47.081  0.383   46.323   47.756      0.006    0.004    4369.0
# sigma          5.157  0.160    4.855    5.444      0.002    0.002    4177.0
# y_pred[0]    158.316  5.158  148.723  167.919      0.081    0.058    4017.0
# y_pred[1]    145.573  5.031  136.252  155.160      0.084    0.059    3593.0
# ...              ...    ...      ...      ...        ...      ...       ...
# y_pred[539]  138.117  5.124  128.057  147.376      0.080    0.056    4148.0
# y_pred[540]  162.391  5.113  153.505  172.687      0.080    0.057    4075.0
# y_pred[541]  164.201  5.108  155.346  174.237      0.084    0.059    3738.0
# y_pred[542]   74.478  5.196   65.612   84.891      0.084    0.059    3829.0
# y_pred[543]  162.734  5.189  153.019  172.805      0.083    0.059    3932.0
#
#              ess_tail  r_hat
# alpha          3060.0    1.0
# beta           2776.0    1.0
# sigma          3191.0    1.0
# y_pred[0]      3952.0    1.0
# y_pred[1]      3829.0    1.0
# ...               ...    ...
# y_pred[539]    3931.0    1.0
# y_pred[540]    3577.0    1.0
# y_pred[541]    3714.0    1.0
# y_pred[542]    3843.0    1.0
# y_pred[543]    3957.0    1.0
#
# [547 rows x 9 columns]

# %% [markdown]
# For a 1 unit (log(kg)) difference in weight, we would expect to see a ~47cm difference in height.

# %%
weights = sorted(df.weight)
mu_ci = [np.percentile(fit_log['alpha']+fit_log['beta']*(np.log(n)-x_bar), 
                       [1.5, 98.5]).tolist() for n in weights]

# %%
plt.figure(figsize=(15,10))
az.plot_hdi(df.weight, fit_log['y_pred'].T, .97, fill_kwargs={'color':'gray', 'alpha':.1})
plt.scatter(df.weight, df.height, alpha=.75)

plt.fill_between(weights, [n[0] for n in mu_ci], [n[1] for n in mu_ci], alpha=.25, color='gray')
plt.title("Height ~ log(weight)")
plt.xlabel("Weight (kg)")
plt.ylabel("Height (cm)")
# Out:
# /Users/jikaasik/miniconda/lib/python3.9/site-packages/arviz/stats/stats.py:456: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   warnings.warn(
# Text(0, 0.5, 'Height (cm)')

# %% [markdown]
# __4H4__

# %% [markdown]
# __4H5__

# %% [markdown]
# __4H6__

# %% [markdown]
# __4H7__

# %% [markdown]
# __4H8__
