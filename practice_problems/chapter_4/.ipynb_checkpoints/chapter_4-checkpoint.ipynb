# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import arviz as az
import stan_jupyter as stan
import pandas as pd

# %% [markdown]
# ## Easy

# %% [markdown]
# __4E1__
#
# The likelihood is line 1: $y_i \sim Normal(\mu, \sigma)$
#
# __4E2__
#
# There are two parameters ($\mu$ and $\sigma$) in the model:
#
#
# \begin{align}
# y_i &\sim Normal(\mu, \sigma) \\
# \mu &\sim Normal(0, 10) \\
# \sigma &\sim Exponential(1)
# \end{align}
#
#
# __4E3__
#
# $$ Pr(\mu, \sigma | y) = \frac{Normal(y|\mu, \sigma) Normal(\mu|0, 10)Exponential(\sigma|1)}
# {\int\int Normal(y|\mu, sigma)Normal(\mu|0, 10)Exponential(\sigma|1)d\mu d\sigma}$$
#
# __4E4__
#
# The linear model is in the second line: $\mu_i = \alpha + \beta x_i$
#
# __4E5__
#
# The model below has three parameters: $\alpha, \beta$ and $\sigma $:
# \begin{align}
# y_i &\sim Normal(\mu, \sigma) \\
# \mu &= \alpha + \beta x_i \\
# \alpha &\sim Normal(0, 10) \\
# \beta &\sim Normal(0,1) \\
# \sigma &\sim Exponential(2)
# \end{align}

# %% [markdown]
# ## Medium

# %% [markdown]
# __4M1__

# %%
size = 10000
sample_mu = stats.norm.rvs(0, 10, size)
sample_sigma = stats.expon.rvs(1, size=size)
sample_y = stats.norm.rvs(sample_mu, sample_sigma, size)

# %%
az.plot_kde(sample_y)
# Out:
# <AxesSubplot:>

# %% [markdown]
# __4M2__
#
# _Skipping because it is specific to R._
#
# __4M3__
#
# \begin{align}
# y_i &\sim Normal(\mu, sigma) \\
# \mu &= \alpha + \beta x_i \\
# \alpha &\sim Normal(0, 10) \\
# \beta &\sim Uniform(0, 1) \\
# \sigma &\sim Exponential(1)
# \end{align}
#
# __4M4__
#
# \begin{align}
# height_{it} &\sim Normal(\mu_{it}, \sigma) \\
# \mu_{it} &= \alpha + \beta * (year_t - \bar y) \\
# \alpha &\sim Normal(140,20) \\
# \beta &\sim Normal(10, 10) \\
# \sigma &\sim Exponential(1) \\
# \end{align}
#
# __4M5__
#
# Since logically students will get taller each year, the slope of $\beta$ should be positive.
#
# \begin{align}
# height_{it} &\sim Normal(\mu_{it}, \sigma) \\
# \mu_{it} &= \alpha + \beta * (year_t - \bar y) \\
# \alpha &\sim Normal(140,20) \\
# \beta &\sim HalfNormal(10, 10) \\
# \sigma &\sim Exponential(1) \\
# \end{align}
#
# __4M6__
#
# If we know the variance between students of the same age <= 64, that means the standard deviation <= 8. In that case, we can change sigma (the standard deviation) to have a uniform prior with a hard ceiling of 8 (and a floor of 0, because a negative standard deviation isn't possible).
#
#
# \begin{align}
# height_{it} &\sim Normal(\mu_{it}, \sigma) \\
# \mu_{it} &= \alpha + \beta * (year_t - \bar y) \\
# \alpha &\sim Normal(140, 20) \\
# \beta &\sim HalfNormal(10, 10) \\
# \sigma &\sim Uniform(0, 8) \\
# \end{align}
#
# __4M7__

# %%
df = pd.read_csv("../../data/Howell1.csv", delimiter=";")
df = df[df.age>=18]

# %%
with open('models/model_4_3.stan', 'r') as f:
    model_code = f.read()

model_data = {"N":len(df),
              "height":df.height.values.tolist(),
              "weight":df.weight.values.tolist()
             }

# %%
posterior = stan.build(model_code, model_data)

fit = posterior.sample(num_chains=4, num_samples=1000)
# Out:
# Building: found in cache, done.
# Messages from stanc:
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_61wmbn97/model_nfeudqqy.stan', line 20, column 41: A normal distribution is given parameter sigma as a scale parameter (argument 2), but sigma was not constrained to be strictly positive.
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_61wmbn97/model_nfeudqqy.stan', line 17, column 21: Argument 50 suggests there may be parameters that are not unit scale; consider rescaling with a multiplier (see manual section 22.12).
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_61wmbn97/model_nfeudqqy.stan', line 17, column 2: Parameter sigma is given a uniform distribution. The uniform distribution is not recommended, for two reasons: (a) Except when there are logical or physical constraints, it is very unusual for you to be sure that a parameter will fall inside a specified range, and (b) The infinite gradient induced by a uniform density can cause difficulties for Stan's sampling algorithm. As a consequence, we recommend soft constraints rather than hard constraints; for example, instead of giving an elasticity parameter a uniform(0,1) distribution, try normal(0.5,0.5).
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_61wmbn97/model_nfeudqqy.stan', line 16, column 2: Parameter beta is given a lognormal distribution, which has strictly positive support, but beta was not constrained to be strictly positive.
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_61wmbn97/model_nfeudqqy.stan', line 15, column 22: Argument 20 suggests there may be parameters that are not unit scale; consider rescaling with a multiplier (see manual section 22.12).
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_61wmbn97/model_nfeudqqy.stan', line 15, column 17: Argument 178 suggests there may be parameters that are not unit scale; consider rescaling with a multiplier (see manual section 22.12).
# Sampling:   0%
# Sampling:   8% (600/8000)
# Sampling:  32% (2600/8000)
# Sampling:  58% (4600/8000)
# Sampling:  82% (6600/8000)
# Sampling: 100% (8000/8000)
# Sampling: 100% (8000/8000), done.
# Messages received during sampling:
#   Gradient evaluation took 1.6e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.16 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -2.81567, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan__pn7ajsd/model_nfeudqqy.stan', line 16, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Gradient evaluation took 1.4e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.14 seconds.
#   Adjust your expectations accordingly!
#   Gradient evaluation took 1.4e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.14 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -0.0394909, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan__pn7ajsd/model_nfeudqqy.stan', line 16, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: lognormal_lpdf: Random variable is -1.26425, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan__pn7ajsd/model_nfeudqqy.stan', line 16, column 2 to column 25)
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: normal_lpdf: Scale parameter is -1.07566, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan__pn7ajsd/model_nfeudqqy.stan', line 20, column 2 to column 48)
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: lognormal_lpdf: Random variable is -0.0763199, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan__pn7ajsd/model_nfeudqqy.stan', line 16, column 2 to column 25)
#   Gradient evaluation took 1.3e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.13 seconds.
#   Adjust your expectations accordingly!

# %%
with open('models/model_4_3_diff.stan', 'r') as f:
    model_code = f.read()

x_bar = df.weight.mean()

model_data = {"N":len(df),
              "height":df.height.values.tolist(),
              "weight":df.weight.values.tolist(),
              "X_BAR":x_bar
             }

# %%
posterior = stan.build(model_code, model_data)
# Out:
# Building: found in cache, done.
# Messages from stanc:
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_pyieffjw/model_est6ylup.stan', line 21, column 49: A normal distribution is given parameter sigma as a scale parameter (argument 2), but sigma was not constrained to be strictly positive.
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_pyieffjw/model_est6ylup.stan', line 18, column 21: Argument 50 suggests there may be parameters that are not unit scale; consider rescaling with a multiplier (see manual section 22.12).
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_pyieffjw/model_est6ylup.stan', line 18, column 2: Parameter sigma is given a uniform distribution. The uniform distribution is not recommended, for two reasons: (a) Except when there are logical or physical constraints, it is very unusual for you to be sure that a parameter will fall inside a specified range, and (b) The infinite gradient induced by a uniform density can cause difficulties for Stan's sampling algorithm. As a consequence, we recommend soft constraints rather than hard constraints; for example, instead of giving an elasticity parameter a uniform(0,1) distribution, try normal(0.5,0.5).
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_pyieffjw/model_est6ylup.stan', line 17, column 2: Parameter beta is given a lognormal distribution, which has strictly positive support, but beta was not constrained to be strictly positive.
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_pyieffjw/model_est6ylup.stan', line 16, column 22: Argument 20 suggests there may be parameters that are not unit scale; consider rescaling with a multiplier (see manual section 22.12).
# Warning in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_pyieffjw/model_est6ylup.stan', line 16, column 17: Argument 178 suggests there may be parameters that are not unit scale; consider rescaling with a multiplier (see manual section 22.12).

# %%
fit_diff = posterior.sample(num_chains=4, num_samples=1000)
# Out:
# Sampling:   0%
# Sampling:  25% (2000/8000)
# Sampling:  50% (4000/8000)
# Sampling:  75% (6000/8000)
# Sampling: 100% (8000/8000)
# Sampling: 100% (8000/8000), done.
# Messages received during sampling:
#   Gradient evaluation took 1.7e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.17 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -87.3168, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -86.3405, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -21.1052, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -4.54493, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -0.376382, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -7838.79, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -221.879, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -1.27954, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.55452, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Gradient evaluation took 2e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.2 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -1769.22, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -1769.31, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -440.724, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -108.589, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -25.7708, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -5.25437, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -0.0400386, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -64654.3, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -1845.68, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -16.3277, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -0.320638, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -0.11041, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -0.655808, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -48.804, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -48.206, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -10.4182, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -2.89637, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Gradient evaluation took 1.8e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.18 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -0.0824986, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -0.203647, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -18.5153, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -0.068903, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -1.592, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -0.685917, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -0.548953, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -2.15818, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -1785.26, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -1770.79, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -440.127, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -97.8636, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -19.8579, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -3.55239, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -37.3402, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: lognormal_lpdf: Random variable is -1.26425, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: normal_lpdf: Scale parameter is -1.07566, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: lognormal_lpdf: Random variable is -0.0763199, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   Gradient evaluation took 1.8e-05 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 0.18 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -4.38541, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -0.0240899, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -0.0605452, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -32.1419, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -31.2612, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -2.35623, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -17.6092, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: lognormal_lpdf: Random variable is -1.74688, but must be nonnegative! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 17, column 2 to column 25)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.714284, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_g1y60f4d/model_est6ylup.stan', line 21, column 2 to column 56)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.

# %%
az.plot_trace(fit)
# Out:
# array([[<AxesSubplot:title={'center':'alpha'}>,
#         <AxesSubplot:title={'center':'alpha'}>],
#        [<AxesSubplot:title={'center':'beta'}>,
#         <AxesSubplot:title={'center':'beta'}>],
#        [<AxesSubplot:title={'center':'sigma'}>,
#         <AxesSubplot:title={'center':'sigma'}>]], dtype=object)

# %%
az.plot_trace(fit_diff)
# Out:
# array([[<AxesSubplot:title={'center':'alpha'}>,
#         <AxesSubplot:title={'center':'alpha'}>],
#        [<AxesSubplot:title={'center':'beta'}>,
#         <AxesSubplot:title={'center':'beta'}>],
#        [<AxesSubplot:title={'center':'sigma'}>,
#         <AxesSubplot:title={'center':'sigma'}>]], dtype=object)

# %%
az.summary(fit_diff)
# Out:
#           mean     sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# alpha  154.598  0.276  154.092  155.124      0.005    0.003    3520.0
# beta     0.902  0.043    0.824    0.983      0.001    0.001    1832.0
# sigma    5.104  0.191    4.740    5.442      0.003    0.002    4823.0
#
#        ess_tail  r_hat
# alpha    2077.0    1.0
# beta     1866.0    1.0
# sigma    3188.0    1.0

# %%
az.summary(fit)
# Out:
#           mean     sd   hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  \
# alpha  114.505  1.961  110.889  118.139      0.057    0.041    1172.0
# beta     0.891  0.043    0.813    0.973      0.001    0.001    1173.0
# sigma    5.099  0.193    4.768    5.486      0.005    0.003    1676.0
#
#        ess_tail  r_hat
# alpha    1363.0    1.0
# beta     1400.0    1.0
# sigma    1646.0    1.0

# %% [markdown]
# The difference is primarily in the intercept $\alpha$, which is 154.6 in the original model (which modeled deviations from the average weight $\bar x$), but 114.5 in this version of the model. The model with $\bar x$ makes slightly more sense, because there the intercept $\alpha = 154.6$ represents the actual average height at the sample mean weight. In this model, the intercept is a slightly odd mathematical artifact that suggests that a person with a weight of 0 would still be ~114.5cm tall, which is not reasonable. The nearly identical slope $\beta$ suggests the model generally believes the same thing about the association between weight and height, but the model with $\bar x$ allows us to also say something valid about the intercept.

# %%
df_fit = fit.to_frame()
df_fit_diff = fit_diff.to_frame()

plt.figure(figsize=(20,10))
_, ax = plt.subplots(1, 2, figsize=(20,5))

idxs = np.random.randint(len(df_fit), size=500)
ax[0].plot(df.weight, df.height, "C0o", alpha=.3)
ax[1].plot(df.weight-x_bar, df.height, "C0o", alpha=.3)
ax[0].set_title("Height ~ weight")
ax[1].set_title("Height ~ weight deviation from mean")

for n in [0,1]:
    ax[n].set_ylabel("Height (cm)")
    ax[n].set_xlabel("Weight (kg)")
    
for idx in idxs:
    ax[0].plot(
        df.weight,
        df_fit['alpha'][idx] + df_fit['beta'][idx]*df.weight,
        color='black',
        alpha=.01,
    )
    ax[1].plot(
        df.weight-x_bar,
        df_fit_diff['alpha'][idx] + df_fit_diff['beta'][idx]*(df.weight-x_bar),
        color='black',
        alpha=.01,
    )

# %%
reg = np.array([df_fit['alpha'], df_fit['beta'], df_fit['sigma']])
diff = np.array([df_fit_diff['alpha'], df_fit_diff['beta'], df_fit_diff['sigma']])

# %%
reg_cov = np.cov(reg)
reg_cov.round(2)
# Out:
# array([[ 3.85, -0.08, -0.01],
#        [-0.08,  0.  ,  0.  ],
#        [-0.01,  0.  ,  0.04]])

# %%
diff_cov = np.cov(diff)
diff_cov.round(2)
# Out:
# array([[0.08, 0.  , 0.  ],
#        [0.  , 0.  , 0.  ],
#        [0.  , 0.  , 0.04]])

# %%
def correlation_from_covariance(covariance): # from https://gist.github.com/wiso/ce2a9919ded228838703c1c7c7dad13b
    v = np.sqrt(np.diag(covariance))
    outer_v = np.outer(v, v)
    correlation = covariance / outer_v
    correlation[covariance == 0] = 0
    return correlation

# %%
correlation_from_covariance(diff_cov).round(2)
# Out:
# array([[1.  , 0.03, 0.03],
#        [0.03, 1.  , 0.01],
#        [0.03, 0.01, 1.  ]])

# %%
correlation_from_covariance(reg_cov).round(2)
# Out:
# array([[ 1.  , -0.99, -0.03],
#        [-0.99,  1.  ,  0.03],
#        [-0.03,  0.03,  1.  ]])

# %% [markdown]
# __4M8__

# %% [markdown]
# ## Hard
#
# __4H1__
