# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
import arviz as az
import stan_jupyter as stan
import pandas as pd

# %%
df = pd.read_csv("sim_data.csv")

# %% [markdown]
# ## Speed test: standardized, logged, normal

# %% [markdown]
# ## Poisson vs. negative binomial vs. normal

# %% [markdown]
# ## Using matrices for covariates

# %% [markdown]
# ## Standardizing by group

# %%
def standardize(df, cols, group_vars):
    group = group_vars
    for col in cols:
        df[f"{col}_std"] = (df[col] - df.groupby(group)[col].transform("mean")) / df.groupby(group)[col].transform("std")

# %%
standardize(df, ["quantity", "price", "competitor_price"], ["sku", "account"])

# %%
with open("stan_code/standardize.stan", "r") as f:
    model_code = f.read()
    
model_data = {
    "N":len(df),
    "N_SKUS":df.sku.nunique(),
    "N_ACCOUNTS":df.account.nunique(),
    "sku":df.sku.tolist(),
    "account":df.account.tolist(),
    "quantity":df.quantity.tolist(),
    "price":df.price_std.tolist(),
    "competitor_price":df.competitor_price_std.tolist(),
}

# %%
# %%capture
posterior = stan.build(model_code, model_data)

# %%
# %%time
#%%capture
fit = posterior.sample(num_chains=4, num_samples=100) # Normal model
# Out:
# Sampling:   0%
# Sampling:   0% (1/4400)
# Sampling:   0% (2/4400)
# Sampling:   0% (3/4400)
# Sampling:   0% (4/4400)
# Sampling:   2% (103/4400)
# Sampling:   5% (202/4400)
# Sampling:   7% (301/4400)
# Sampling:   9% (400/4400)
# Sampling:  11% (500/4400)
# Sampling:  14% (600/4400)
# Sampling:  16% (700/4400)
# Sampling:  18% (800/4400)
# Sampling:  20% (900/4400)
# Sampling:  23% (1000/4400)
# Sampling:  25% (1100/4400)
# Sampling:  27% (1200/4400)
# Sampling:  30% (1300/4400)
# Sampling:  32% (1400/4400)
# Sampling:  34% (1500/4400)
# Sampling:  36% (1600/4400)
# Sampling:  39% (1700/4400)
# Sampling:  41% (1800/4400)
# Sampling:  43% (1900/4400)
# Sampling:  45% (2000/4400)
# Sampling:  48% (2100/4400)
# Sampling:  50% (2200/4400)
# Sampling:  52% (2300/4400)
# Sampling:  55% (2400/4400)
# Sampling:  57% (2500/4400)
# Sampling:  59% (2600/4400)
# Sampling:  61% (2700/4400)
# Sampling:  64% (2800/4400)
# Sampling:  66% (2900/4400)
# Sampling:  68% (3000/4400)
# Sampling:  70% (3100/4400)
# Sampling:  73% (3200/4400)
# Sampling:  75% (3300/4400)
# Sampling:  77% (3400/4400)
# Sampling:  80% (3500/4400)
# Sampling:  82% (3600/4400)
# Sampling:  84% (3700/4400)
# Sampling:  84% (3701/4400)
# Sampling:  86% (3801/4400)
# Sampling:  86% (3802/4400)
# Sampling:  89% (3902/4400)
# Sampling:  91% (4002/4400)
# Sampling:  91% (4003/4400)
# Sampling:  91% (4004/4400)
# Sampling:  93% (4103/4400)
# Sampling:  96% (4202/4400)
# Sampling:  98% (4301/4400)
# Sampling: 100% (4400/4400)
# Sampling: 100% (4400/4400), done.
# Messages received during sampling:
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: normal_lpdf: Scale parameter is -1.21329, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_q49vru2v/model_jpdjyw74.stan', line 37, column 1 to column 30)
#   Gradient evaluation took 0.000713 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 7.13 seconds.
#   Adjust your expectations accordingly!
#   Gradient evaluation took 0.000701 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 7.01 seconds.
#   Adjust your expectations accordingly!
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: normal_lpdf: Scale parameter is -1.21973, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_q49vru2v/model_jpdjyw74.stan', line 37, column 1 to column 30)
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: normal_lpdf: Scale parameter is -0.974582, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_q49vru2v/model_jpdjyw74.stan', line 37, column 1 to column 30)
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: normal_lpdf: Scale parameter is -0.972442, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_q49vru2v/model_jpdjyw74.stan', line 37, column 1 to column 30)
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: normal_lpdf: Scale parameter is -1.67927, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_q49vru2v/model_jpdjyw74.stan', line 37, column 1 to column 30)
#   Gradient evaluation took 0.000599 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 5.99 seconds.
#   Adjust your expectations accordingly!
#   Gradient evaluation took 0.000621 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 6.21 seconds.
#   Adjust your expectations accordingly!
# CPU times: user 8.27 s, sys: 980 ms, total: 9.25 s
# Wall time: 10min

# %%
# %%time
#%%capture
fit = posterior.sample(num_chains=4, num_samples=1000) # Standardized
# Out:
# Sampling:   0%
# Sampling:   0% (1/8000)
# Sampling:   0% (2/8000)
# Sampling:   0% (3/8000)
# Sampling:   0% (4/8000)
# Sampling:   1% (103/8000)
# Sampling:   3% (202/8000)
# Sampling:   4% (301/8000)
# Sampling:   5% (401/8000)
# Sampling:   6% (500/8000)
# Sampling:   8% (600/8000)
# Sampling:   9% (700/8000)
# Sampling:  10% (800/8000)
# Sampling:  11% (900/8000)
# Sampling:  12% (1000/8000)
# Sampling:  14% (1100/8000)
# Sampling:  15% (1200/8000)
# Sampling:  16% (1300/8000)
# Sampling:  18% (1400/8000)
# Sampling:  19% (1500/8000)
# Sampling:  20% (1600/8000)
# Sampling:  21% (1700/8000)
# Sampling:  22% (1800/8000)
# Sampling:  24% (1900/8000)
# Sampling:  25% (2000/8000)
# Sampling:  26% (2100/8000)
# Sampling:  28% (2200/8000)
# Sampling:  29% (2300/8000)
# Sampling:  30% (2400/8000)
# Sampling:  31% (2500/8000)
# Sampling:  32% (2600/8000)
# Sampling:  34% (2700/8000)
# Sampling:  35% (2800/8000)
# Sampling:  36% (2900/8000)
# Sampling:  38% (3000/8000)
# Sampling:  39% (3100/8000)
# Sampling:  40% (3200/8000)
# Sampling:  41% (3300/8000)
# Sampling:  42% (3400/8000)
# Sampling:  44% (3500/8000)
# Sampling:  44% (3501/8000)
# Sampling:  45% (3602/8000)
# Sampling:  46% (3702/8000)
# Sampling:  48% (3803/8000)
# Sampling:  49% (3902/8000)
# Sampling:  50% (4002/8000)
# Sampling:  51% (4101/8000)
# Sampling:  52% (4200/8000)
# Sampling:  54% (4300/8000)
# Sampling:  55% (4401/8000)
# Sampling:  56% (4501/8000)
# Sampling:  58% (4601/8000)
# Sampling:  59% (4701/8000)
# Sampling:  60% (4801/8000)
# Sampling:  61% (4900/8000)
# Sampling:  62% (5000/8000)
# Sampling:  64% (5100/8000)
# Sampling:  65% (5200/8000)
# Sampling:  66% (5300/8000)
# Sampling:  68% (5400/8000)
# Sampling:  69% (5500/8000)
# Sampling:  70% (5600/8000)
# Sampling:  71% (5700/8000)
# Sampling:  72% (5800/8000)
# Sampling:  74% (5900/8000)
# Sampling:  75% (6000/8000)
# Sampling:  76% (6100/8000)
# Sampling:  78% (6200/8000)
# Sampling:  79% (6300/8000)
# Sampling:  80% (6400/8000)
# Sampling:  81% (6500/8000)
# Sampling:  82% (6600/8000)
# Sampling:  84% (6700/8000)
# Sampling:  85% (6800/8000)
# Sampling:  86% (6900/8000)
# Sampling:  88% (7000/8000)
# Sampling:  89% (7100/8000)
# Sampling:  90% (7200/8000)
# Sampling:  91% (7300/8000)
# Sampling:  92% (7400/8000)
# Sampling:  94% (7500/8000)
# Sampling:  95% (7600/8000)
# Sampling:  96% (7700/8000)
# Sampling:  98% (7800/8000)
# Sampling:  99% (7900/8000)
# Sampling: 100% (8000/8000)
# Sampling: 100% (8000/8000), done.
# Messages received during sampling:
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: normal_lpdf: Scale parameter is -1.65897, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 42, column 2 to column 42)
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: normal_lpdf: Scale parameter is -0.939869, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 41, column 2 to column 38)
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: normal_lpdf: Scale parameter is -0.317504, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 42, column 2 to column 42)
#   Gradient evaluation took 0.001144 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 11.44 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Location parameter[1] is inf, but must be finite! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 52, column 2 to column 31)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Location parameter[1] is inf, but must be finite! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 52, column 2 to column 31)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Location parameter[1] is inf, but must be finite! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 52, column 2 to column 31)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Location parameter[1] is inf, but must be finite! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 52, column 2 to column 31)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Location parameter[1] is inf, but must be finite! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 52, column 2 to column 31)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Location parameter[1] is inf, but must be finite! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 52, column 2 to column 31)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Location parameter[1] is inf, but must be finite! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 52, column 2 to column 31)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Location parameter[1] is inf, but must be finite! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 52, column 2 to column 31)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0515069, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0525966, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.128028, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.437821, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 42, column 2 to column 42)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00223957, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00877808, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0013155, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00553122, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.226, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0393635, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0296919, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0906071, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.150742, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0202499, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00438392, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0203829, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0161177, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00797168, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0228005, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.016977, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.328106, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 41, column 2 to column 38)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.000637556, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0127479, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00100123, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.016168, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0450329, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0211813, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0645816, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00454215, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0123888, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.037819, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0184992, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00704617, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.116168, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0393089, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0482936, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0513444, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00325202, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00186915, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00585978, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0291526, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0253551, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0381394, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0156213, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00398896, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0479466, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0929697, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0221067, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0337202, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0288546, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0908954, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.000424175, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00627029, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Rejecting initial value:
#     Error evaluating the log probability at the initial value.
#   Exception: normal_lpdf: Scale parameter is -1.42352, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   Gradient evaluation took 0.000909 seconds
#   1000 transitions using 10 leapfrog steps per transition would take 9.09 seconds.
#   Adjust your expectations accordingly!
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Location parameter[1] is inf, but must be finite! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 52, column 2 to column 31)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -1.22221, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 41, column 2 to column 38)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Location parameter[1] is inf, but must be finite! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 52, column 2 to column 31)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Location parameter[1] is inf, but must be finite! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 52, column 2 to column 31)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Location parameter[1] is inf, but must be finite! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 52, column 2 to column 31)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Location parameter[1] is inf, but must be finite! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 52, column 2 to column 31)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Location parameter[1] is inf, but must be finite! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 52, column 2 to column 31)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -170.711, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 41, column 2 to column 38)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -4.47322, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 41, column 2 to column 38)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Location parameter[1] is inf, but must be finite! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 52, column 2 to column 31)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00817216, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0139641, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.336188, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00803967, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0462572, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00368849, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.014828, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0383153, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
# ...
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.324462, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -1.59588, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 44, column 2 to column 50)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0863579, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 44, column 2 to column 50)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0508777, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0126018, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00691591, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0146292, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0147508, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00863443, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0297551, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 44, column 2 to column 50)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00412636, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0278434, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.000190793, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0284177, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00291329, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0184417, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00973693, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00227727, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00249133, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0163534, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00270283, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0133714, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.00824144, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0522782, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0669124, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0178756, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0114425, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
#   Informational Message: The current Metropolis proposal is about to be rejected because of the following issue:
#   Exception: normal_lpdf: Scale parameter is -0.0157306, but must be positive! (in '/var/folders/lx/ncfwc0_n057_shk9g1g0926r0000gn/T/httpstan_0ueks49s/model_og5fguf6.stan', line 43, column 2 to column 46)
#   If this warning occurs sporadically, such as for highly constrained variable types like covariance matrices, then the sampler is fine,
#   but if this warning occurs often then your model may be either severely ill-conditioned or misspecified.
# CPU times: user 43.7 s, sys: 4.03 s, total: 47.8 s
# Wall time: 3min 19s

# %%
az.summary(fit)
# Out:
# /Users/jikaasik/miniconda/lib/python3.9/site-packages/arviz/stats/diagnostics.py:561: RuntimeWarning: invalid value encountered in double_scalars
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
#                     mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# alpha             36.561  1.072  34.576   38.703      0.037    0.026
# beta              -3.188  0.679  -4.547   -1.875      0.020    0.014
# gamma              1.850  0.111   1.642    2.057      0.002    0.001
# sigma              5.530  0.078   5.388    5.682      0.002    0.001
# sku_intercept[0]  -0.574  0.880  -2.247    1.129      0.027    0.023
# ...                  ...    ...     ...      ...        ...      ...
# gap[2496]          4.493  3.341   0.002   10.322      0.056    0.039
# gap[2497]          6.252  4.395   0.002   14.080      0.070    0.050
# gap[2498]         12.291  5.332   1.885   21.978      0.084    0.060
# gap[2499]          9.184  5.148   0.176   17.822      0.081    0.058
# mae                6.226  0.093   6.050    6.399      0.001    0.001
#
#                   ess_bulk  ess_tail  r_hat
# alpha                894.0     732.0   1.00
# beta                1253.0     852.0   1.00
# gamma               3203.0    2131.0   1.00
# sigma               2567.0    2030.0   1.00
# sku_intercept[0]    1160.0    1054.0   1.01
# ...                    ...       ...    ...
# gap[2496]           3578.0    3708.0   1.00
# gap[2497]           3936.0    3958.0   1.00
# gap[2498]           4093.0    3993.0   1.00
# gap[2499]           4029.0    3927.0   1.00
# mae                 3891.0    3743.0   1.00
#
# [10029 rows x 9 columns]

# %%
az.plot_kde([n.mean() for n in fit['account_slope']])
# Out:
# <AxesSubplot:>

# %%
az.plot_kde([n.mean() for n in fit['y_pred']])
az.plot_kde([n.mean() for n in fit['y']], plot_kwargs={"color":'r'})
# Out:
# <AxesSubplot:>
