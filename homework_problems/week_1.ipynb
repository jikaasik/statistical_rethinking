# %%
import numpy as np
import matplotlib.pyplot as plt
import arviz as az
import scipy.stats as stats

# %% [markdown]
# ## Question 1

# %%
size = 10000
p_grid = np.linspace(0, 1, size)
prior = np.repeat(1, size)

likelihood = stats.binom.pmf(4, 15, p_grid)
posterior = likelihood * prior
posterior = posterior / sum(posterior)

# %%
samples = np.random.choice(p_grid, p=posterior, size=size, replace=True)

# %%
np.mean(samples)
# Out:
# 0.2932762976297629

# %%
plt.plot(posterior)

# %%
az.plot_kde(samples)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Question 2

# %%
prior = np.where(p_grid<.5, 0, 1)

likelihood = stats.binom.pmf(4, 6, p_grid)
posterior = likelihood * prior
posterior = posterior / sum(posterior)

samples = np.random.choice(p_grid, p=posterior, size=size, replace=True)

# %%
np.mean(samples)
# Out:
# 0.6905665466546654

# %%
plt.plot(posterior)

# %% [markdown]
# ## Question 3

# %%
low_hpdi, high_hpdi = az.hdi(samples)
print(low_hpdi,":",high_hpdi)
# Out:
# 0.5000500050005001 : 0.8743874387438744

# %%
low_pi, high_pi = np.percentile(samples, [5.5, 94.5])
print(low_pi, ":", high_pi)
# Out:
# 0.5242469246924693 : 0.8786878687868788

# %%
az.plot_kde(samples)
plt.axvline(x=low_hpdi, color='r', linestyle='--', alpha=.3)
plt.axvline(x=high_hpdi, color='r', linestyle='--', alpha=.3)
plt.axvline(x=low_pi, color='b', linestyle='--', alpha=.3)
plt.axvline(x=high_pi, color='b', linestyle='--', alpha=.3)

# %%
plt.axvline(x=sum(birth1+birth2), color='r', linestyle='--', alpha=.3)

# %%
plt.plot(samples, "o", alpha=.1)

# %% [markdown]
# The HPDI is slightly smaller. If we had only the information in the interval...

# %% [markdown]
# ## Question 4
